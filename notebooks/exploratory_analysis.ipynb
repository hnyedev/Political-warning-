# %% [markdown]
# # Exploratory Analysis — CAMEL-OASIS MX Surveillance Simulation
#
# Load structured personas, graph metrics, and evaluation results for ad-hoc analysis.

# %%
from pathlib import Path
import json
import pandas as pd

ROOT = Path("..").resolve()
structured = ROOT / "data/processed/personas_structured.jsonl"
evaluation = ROOT / "reports/evaluation_report.json"

if structured.exists():
    df = pd.read_json(structured, lines=True)
    display(df.head())
else:
    print("Run phase 1 extraction first.")

if evaluation.exists():
    report = json.loads(evaluation.read_text())
    print("Political warning:", report.get("political_warning_triggered"))
